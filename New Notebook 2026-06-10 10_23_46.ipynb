# %%
# %sql

DROP TABLE IF EXISTS az_adb_simbus_training.retail.gold_sales_summary;
DROP TABLE IF EXISTS az_adb_simbus_training.retail.gold_product_performance;
DROP TABLE IF EXISTS az_adb_simbus_training.retail.gold_repeat_customers;
